# %%
#导入qstock模块
import qstock as qs
import pandas as pd
from qstock import plot

pd.set_option('display.width', 800)

# %% [markdown]
# # 获取沪深A股最新行情指标

# %%
df=qs.realtime_data()
#查看前几行
df.head(2)
# Out:
#        代码     名称     涨幅     最新     最高     最低     今开    换手率    量比    市盈率       成交量           成交额     昨收           总市值         流通市值                   时间
# 0  301112   信邦智能  20.00  38.34  38.34  34.04  34.04  34.83  3.84  65.69   87725.0  3.225097e+08  31.95  4.227621e+09  965555250.0  2023-01-20 15:34:06
# 1  300089  *ST文化  18.12   1.63   1.66   1.43   1.43  10.30  1.92  -9.72  417822.0  6.484182e+07   1.38  7.841227e+08  661171899.0  2023-01-20 15:34:45

# %% [markdown]
# # 获取沪深市场指定股票前十大股东信息

# %%
df=qs.stock_holder_top10('中国平安', n=2)

# %%
df
# Out:
#         代码          日期                                  股东名称  持股数(亿)  持股比例(%)        增减  变动率(%)
# 0   601318  2022-09-30                       香港中央结算(代理人)有限公司  67.650    37.01   -17.30万    0.00
# 1   601318  2022-09-30                           深圳市投资控股有限公司   9.627     5.27        不变    0.00
# 2   601318  2022-09-30                            香港中央结算有限公司   6.299     3.45  -214.41万   -0.34
# 3   601318  2022-09-30                          中国证券金融股份有限公司   5.475     2.99        不变    0.00
# 4   601318  2022-09-30                        中央汇金资产管理有限责任公司   4.703     2.57        不变    0.00
# 5   601318  2022-09-30                              商发控股有限公司   4.436     2.43        不变    0.00
# 6   601318  2022-09-30                              深业集团有限公司   2.577     1.41        不变    0.00
# 7   601318  2022-09-30                中国平安保险(集团)股份有限公司长期服务计划   2.545     1.39        不变    0.00
# 8   601318  2022-09-30  Plenty Ace Investments (SPV) Limited   2.191     1.20        不变    0.00
# 9   601318  2022-09-30                大成基金-农业银行-大成中证金融资产管理计划   2.019     1.10        不变    0.00
# 10  601318  2022-06-30                       香港中央结算(代理人)有限公司  67.650    37.01   9470.00    0.00
# 11  601318  2022-06-30                           深圳市投资控股有限公司   9.627     5.27        不变    0.00
# 12  601318  2022-06-30                            香港中央结算有限公司   6.321     3.46  2231.50万    3.66
# 13  601318  2022-06-30                          中国证券金融股份有限公司   5.475     2.99        不变    0.00
# 14  601318  2022-06-30                        中央汇金资产管理有限责任公司   4.703     2.57        不变    0.00
# 15  601318  2022-06-30                              商发控股有限公司   4.436     2.43        不变    0.00
# 16  601318  2022-06-30                              深业集团有限公司   2.577     1.41        不变    0.00
# 17  601318  2022-06-30                中国平安保险(集团)股份有限公司长期服务计划   2.545     1.39   -19.86万   -0.08
# 18  601318  2022-06-30  Plenty Ace Investments (SPV) Limited   2.191     1.20        不变    0.00
# 19  601318  2022-06-30                大成基金-农业银行-大成中证金融资产管理计划   2.019     1.10        不变    0.00

# %% [markdown]
# # 获取A股指数

# %%
# index_list=['上证指数','创业板指','沪深300','道琼斯','标普500','纳斯达克']
index_list=['上证指数', '沪深300']
data=qs.get_price(index_list, fqt=2)
data.head(2)

# %%
import qstock as qs

df=qs.get_data('沪深300', start='2006-06-01',end='2022-10-20', timeouts=200)
# df=qs.get_data('沪深300', timeouts=200)
df.head()
# Out:
# 100%|██████████| 1/1 [00:29<00:00, 29.72s/it]
#              name    code     open     high      low    close    volume  \
# date
# 2006-06-01  沪深300  000300  1364.18  1403.27  1362.94  1402.88  53493453
# 2006-06-02  沪深300  000300  1406.62  1411.78  1382.00  1390.12  64109162
# 2006-06-05  沪深300  000300  1391.46  1403.30  1362.72  1403.16  55101819
# 2006-06-06  沪深300  000300  1400.27  1413.11  1391.90  1399.14  46835278
# 2006-06-07  沪深300  000300  1398.18  1398.18  1319.70  1320.23  52047647
#
#                 turnover  turnover_rate
# date
# 2006-06-01  3.138349e+10           0.18
# 2006-06-02  3.740732e+10           0.22
# 2006-06-05  2.978474e+10           0.19
# 2006-06-06  2.649786e+10           0.16
# 2006-06-07  3.107629e+10           0.18

# %%
df[['close']].shape
# Out:
# (3987, 1)

# %% [markdown]
# # 获取股票多期时间的面板数据
# * name	code	open	high	low	close	volume	turnover	turnover_rate

# %%
df=qs.get_data('中国平安',start='2022-06-01',end='2022-10-20')
df=qs.get_data('沪深300',start='2022-06-01',end='2022-10-20')

#df.tail()
#使用默认参数
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]

# %%
plot.kline(df)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a380d2333b364d9b81fd8cc3a1299d59" style="width:100%; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a380d2333b364d9b81fd8cc3a1299d59 = echarts.init(
#                     document.getElementById('a380d2333b364d9b81fd8cc3a1299d59'), 'white', {renderer: 'canvas'});
#                     var barData=[[41.83, 41.75], [41.38, 41.58], [41.57, 41.84], [41.84, 41.73], [41.83, 42.17], [42.28, 42.2], [41.93, 42.52], [42.08, 41.72], [41.48, 42.8], [42.58, 45.23], [44.96, 44.08], [43.95, 44.61], [44.8, 44.44], [44.76, 45.21], [45.28, 44.48], [44.71, 45.33], [45.51, 45.84], [45.93, 45.88], [45.9, 45.98], [45.97, 45.87], [45.88, 45.77], [45.78, 45.39], [45.28, 45.54], [45.56, 45.69], [45.7, 44.93], [44.73, 44.68], [44.99, 44.9], [44.69, 44.46], [44.46, 44.59], [44.5, 44.16], [43.98, 42.68], [42.69, 41.79], [41.83, 42.53], [42.5, 42.48], [42.86, 42.48], [42.31, 41.82], [41.88, 42.13], [42.08, 42.0], [42.03, 42.28], [42.14, 41.87], [41.98, 41.8], [41.87, 41.2], [41.19, 40.92], [40.61, 40.25], [40.22, 39.91], [40.2, 40.16], [40.37, 40.62], [40.38, 40.26], [40.25, 40.04], [40.04, 39.48], [39.67, 40.54], [40.34, 40.69], [40.51, 40.22], [40.42, 40.07], [40.13, 40.37], [40.23, 39.89], [39.78, 40.05], [39.93, 40.23], [40.1, 39.8], [40.43, 40.69], [40.93, 42.18], [42.19, 42.2], [41.88, 42.15], [42.06, 41.97], [41.79, 42.92], [42.68, 42.73], [42.97, 42.78], [42.58, 42.88], [42.98, 42.98], [42.68, 42.68], [42.92, 42.92], [43.07, 43.77], [43.76, 44.14], [43.61, 43.73], [43.75, 44.17], [43.9, 43.01], [43.0, 43.01], [43.23, 42.32], [42.18, 42.23], [41.68, 41.56], [41.49, 42.1], [41.82, 41.57], [41.51, 41.52], [41.28, 40.97], [41.31, 40.4], [40.43, 40.66], [40.66, 40.51], [40.75, 40.28], [40.29, 41.0], [40.88, 40.44], [40.83, 41.02], [40.79, 41.18], [41.48, 40.83], [40.73, 40.35], [40.4, 40.01]]
#                 var option_a380d2333b364d9b81fd8cc3a1299d59 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "klines",
#             "colorBy": "series",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     41.83,
#                     41.75,
#                     41.49,
#                     42.13
#                 ],
#                 [
#                     41.38,
#                     41.58,
#                     41.13,
#                     41.61
#                 ],
#                 [
#                     41.57,
#                     41.84,
#                     40.91,
#                     41.85
#                 ],
#                 [
#                     41.84,
#                     41.73,
#                     41.53,
#                     41.96
#                 ],
#                 [
#                     41.83,
#                     42.17,
#                     41.64,
#                     42.29
#                 ],
#                 [
#                     42.28,
#                     42.2,
#                     42.05,
#                     42.61
#                 ],
#                 [
#                     41.93,
#                     42.52,
#                     41.66,
#                     42.58
#                 ],
#                 [
#                     42.08,
#                     41.72,
#                     41.6,
#                     42.18
#                 ],
#                 [
#                     41.48,
#                     42.8,
#                     41.38,
#                     42.83
#                 ],
#                 [
#                     42.58,
#                     45.23,
#                     42.49,
#                     46.14
#                 ],
#                 [
#                     44.96,
#                     44.08,
#                     44.08,
#                     45.08
#                 ],
#                 [
#                     43.95,
#                     44.61,
#                     43.83,
#                     44.84
#                 ],
#                 [
#                     44.8,
#                     44.44,
#                     44.13,
#                     44.93
#                 ],
#                 [
#                     44.76,
#                     45.21,
#                     44.53,
#                     45.86
#                 ],
#                 [
#                     45.28,
#                     44.48,
#                     44.48,
#                     45.4
#                 ],
#                 [
#                     44.71,
#                     45.33,
#                     44.71,
#                     45.58
#                 ],
#                 [
#                     45.51,
#                     45.84,
#                     45.3,
#                     45.93
#                 ],
#                 [
#                     45.93,
#                     45.88,
#                     45.58,
#                     46.18
#                 ],
#                 [
#                     45.9,
#                     45.98,
#                     45.43,
#                     46.27
#                 ],
#                 [
#                     45.97,
#                     45.87,
#                     45.66,
#                     46.52
#                 ],
#                 [
#                     45.88,
#                     45.77,
#                     45.54,
#                     46.28
#                 ],
#                 [
#                     45.78,
#                     45.39,
#                     45.2,
#                     46.06
#                 ],
#                 [
#                     45.28,
#                     45.54,
#                     44.88,
#                     45.58
#                 ],
#                 [
#                     45.56,
#                     45.69,
#                     45.46,
#                     46.63
#                 ],
#                 [
#                     45.7,
#                     44.93,
#                     44.83,
#                     45.71
#                 ],
#                 [
#                     44.73,
#                     44.68,
#                     44.67,
#                     45.22
#                 ],
#                 [
#                     44.99,
#                     44.9,
#                     44.76,
#                     45.46
#                 ],
#                 [
#                     44.69,
#                     44.46,
#                     44.3,
#                     44.85
#                 ],
#                 [
#                     44.46,
#                     44.59,
#                     44.2,
#                     44.82
#                 ],
#                 [
#                     44.5,
#                     44.16,
#                     44.08,
#                     44.71
#                 ],
#                 [
#                     43.98,
#                     42.68,
#                     42.51,
#                     44.12
#                 ],
#                 [
#                     42.69,
#                     41.79,
#                     41.78,
#                     43.17
#                 ],
#                 [
#                     41.83,
#                     42.53,
#                     41.8,
#                     42.77
#                 ],
#                 [
#                     42.5,
#                     42.48,
#                     41.98,
#                     42.85
#                 ],
#                 [
#                     42.86,
#                     42.48,
#                     42.44,
#                     42.91
#                 ],
#                 [
#                     42.31,
#                     41.82,
#                     41.73,
#                     42.33
#                 ],
#                 [
#                     41.88,

# %%
import qstock as qs

# fqt:复权类型，0：不复权，1：前复权；2：后复权，默认前复权
df=qs.get_data('605056',start='2014-06-01',end='2022-10-10')
df['up'] = df['close'].pct_change()
df.shape
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12.27it/s]
# (295, 10)

# %%
df = qs.get_data('600734', start='2020-10-18', end='2020-10-25', fqt=2)
# df['up'] = df['close'].pct_change()
df
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 16.86it/s]
#             name    code  open  high   low  close  volume    turnover  \
# date
# 2020-10-19  ST实达  600734 -0.12 -0.08 -0.17  -0.12   47445   7727470.0
# 2020-10-20  ST实达  600734 -0.12 -0.12 -0.25  -0.12   61148   9907247.0
# 2020-10-21  ST实达  600734 -0.12 -0.12 -0.46  -0.42  115959  18360999.0
# 2020-10-22  ST实达  600734 -0.46 -0.46 -0.75  -0.63  112564  16955896.0
# 2020-10-23  ST实达  600734 -0.67 -0.54 -0.71  -0.71   82376  12416151.0
#
#             turnover_rate
# date
# 2020-10-19           0.89
# 2020-10-20           1.14
# 2020-10-21           2.17
# 2020-10-22           2.10
# 2020-10-23           1.54

# %%
for idx, row in df.iterrows():
    print(idx, type(idx), type(idx.to_pydatetime()))
    break
# Out:
# 2015-05-25 00:00:00 <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'datetime.datetime'>

# %%
import qstock as qs 

qs.stock_basics(['600793', '000736'])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 16.44it/s]
#        代码    名称           净利润           总市值          流通市值   所处行业  市盈率(动)  \
# 0  600793  宜宾纸业  2.731224e+07  2.266140e+09  2.266140e+09   造纸印刷   62.23
# 0  000736  中交地产 -1.741826e+08  1.145379e+10  1.145379e+10  房地产开发  -49.32
#
#     市净率   ROE        毛利率       净利率
# 0  3.46  4.25   8.256612  1.519619
# 0  3.74 -5.51  11.450951  0.825297

# %%
qs.
