# %% [markdown]
# # tutorials
#
#    * [tutorialspoint tutorial](https://www.tutorialspoint.com/spring_boot/spring_boot_application_properties.htm)
#
# # 注解
#
# ## @EnableAutoConfiguration:
#
# * Spring Boot Auto Configuration automatically configures your Spring application based on the JAR dependencies you added in the project. For example, if MySQL database is on your class path, but you have not configured any database connection, then Spring Boot auto configures an in-memory database.
# * https://www.tutorialspoint.com/spring_boot/spring_boot_introduction.htm
#
# ```java
# import org.springframework.boot.SpringApplication;
# import org.springframework.boot.autoconfigure.EnableAutoConfiguration;
#
# @EnableAutoConfiguration
# public class DemoApplication {
#    public static void main(String[] args) {
#       SpringApplication.run(DemoApplication.class, args);
#    }
# }
# ```
#
# ## @SpringBootApplication
#
# * @SpringBootApplication annotation includes Auto- Configuration, Component Scan, and Spring Boot Configuration.
# * If you added @SpringBootApplication annotation to the class, you do not need to add the @EnableAutoConfiguration, @ComponentScan and @SpringBootConfiguration annotation. The @SpringBootApplication annotation includes all other annotations.
#
#
# ## @RequestMapping
#
# * used to define the mapping between the URL and the method.
#   * @RequestMapping(value="/", method=RequestMethod.GET)
#   * @RequestMapping(value="/", method=RequestMethod.POST)
#   * @RequestMapping(value="/", method=RequestMethod.PUT)
#   * @RequestMapping(value="/", method=RequestMethod.DELETE)
#   * @RequestMapping(value = "/products")
# public ResponseEntity<Object> getProducts() { }
#
# * @RequestMapping注解可以用于类级别或方法级别，用于映射HTTP请求到特定的处理方法。当它被用于类级别时，它指定了该类所处理的根URL路径。当它被用于方法级别时，它指定了该方法所处理的URL路径。
#
#
# ## @RequestBody
#
# * used to define the request body content type.
#
# ## @ResponseBody
#
# * used to define the response body content type.
#
# ## @RestController
#
# * used to define the RESTful web services. It serves JSON, XML and custom response.
#
# ## @ServiceComponent
#
# * are the class file which contains @Service annotation. These class files are used to write business logic in a different layer, separated from @RestController class file.
# *
#
# ## @Scheduled
#
# * https://www.tutorialspoint.com/spring_boot/spring_boot_scheduling.htm
#
# ## @Componet
#
# # properties
#
# * https://www.tutorialspoint.com/spring_boot/spring_boot_application_properties.htm
#
#
# # Interceptor
#
# * perform operations under the following situations:
#   * Before sending the request to the controller
#   * Before sending the response to the client
# * https://www.tutorialspoint.com/spring_boot/spring_boot_interceptor.htm
#
#
# # Thymeleaf
#
# * Thymeleaf is a Java-based library used to create a web application. It provides a good support for serving a XHTML/HTML5 in web applications.
#
#
# # eureka 注册中心
#
# * https://www.tutorialspoint.com/spring_boot/spring_boot_service_registration_with_eureka.htm

# %%
from mii import pipeline
pipe = pipeline("Qwen/Qwen-7B-Chat")
output = pipe(["Hello, my name is", "DeepSpeed is"], max_new_tokens=128)
print(output)

# 部署
import mii
mii.serve("Qwen/Qwen-7B-Chat")


client = mii.client("Qwen/Qwen-7B-Chat")
output = client.generate("Deepspeed is", max_new_tokens=128)
print(output)
