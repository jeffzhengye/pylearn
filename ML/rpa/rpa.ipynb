# %% [markdown]
# # 微软UNIPath
#
# * https://uipath-cn-website.shangkentech.com/solutions/technology/microsoft-automation/
#
# # UiBot
#
# * https://www.uibot.com.cn/
# * 通过模拟人工操作键盘鼠标，自动处理计算机中规则清晰、批量重复的工作与任务。
# * 机器人平台：可接单和服务
#
# # python rpa
#
# ## rpaframework
#
# * Documentation: https://rpaframework.org/
# * https://github.com/robocorp/rpaframework
#
# ## wechat rpa
#
# * https://github.com/yihleego/robotic-process-automation
#
# ## rpa tagui
#
# * https://github.com/tebelorg/RPA-Python
#
# ##
#
# # 业务
#
# ![image.png](attachment:image.png)
