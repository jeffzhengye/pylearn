# %% [markdown]
# # facefusion
# ## troubleshooting
#
# * facefusion/core.py 删除 opennsfw2预测部分。
# if predict_video(facefusion.globals.target_path):
# 		return
#
# # damo cv_unet-image-face-fusion_damo
#
# * cv_unet-image-face-fusion_damo
#
#
# ![image.png](attachment:image.png)

# %%
import cv2
from modelscope.outputs import OutputKeys
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

image_face_fusion = pipeline(Tasks.image_face_fusion, 
                       model='damo/cv_unet-image-face-fusion_damo')
template_path = 'https://modelscope.oss-cn-beijing.aliyuncs.com/test/images/facefusion_template.jpg'
user_path = 'https://modelscope.oss-cn-beijing.aliyuncs.com/test/images/facefusion_user.jpg'
result = image_face_fusion(dict(template=template_path, user=user_path))

cv2.imwrite('result.png', result[OutputKeys.OUTPUT_IMG])
print('finished!')

# %%
template_path = r"D:\wps\剪印\auto_generate\girlsteam\1afe83e8f5cfb015096b233bb8724686-[AIGC GIRLS]The 022 Girls\e0a8c86c135a81df0c1fc43a8b31000f_cleaned_cropped_super_resolution.WEBP"

template_path = r"D:\wps\剪印\auto_generate\amateur\0b39a97fb6441ada9bbbb5b85bbff3e2-绝美的盛世美颜\83891edc6709a9bf243a2d66bc9ea449_cleaned_cropped_super_resolution.WEBP"

user_path = r"C:\Users\73915\Downloads\微信图片_20231229235134.png"

result = image_face_fusion(dict(template=template_path, user=user_path))

cv2.imwrite('liuyifei5.png', result[OutputKeys.OUTPUT_IMG])
# Out:
# 2023-12-30 00:02:53,066 - modelscope - INFO - model inference done
# True

# %%
user_path = r"C:\Users\73915\Downloads\5724e6f2fa1c31214b878a2a79206451.jpg"

result = image_face_fusion(dict(template=template_path, user=user_path))

cv2.imwrite('zhaolushi3.png', result[OutputKeys.OUTPUT_IMG])
# Out:
# 2023-12-30 00:03:07,600 - modelscope - INFO - model inference done
# True

# %%
user_path = r"C:\Users\73915\Downloads\4.png"

result = image_face_fusion(dict(template=template_path, user=user_path))

cv2.imwrite('lazha5.png', result[OutputKeys.OUTPUT_IMG])
# Out:
# 2023-12-30 00:05:34,401 - modelscope - INFO - model inference done
# True

# %%
user_path = r"C:\Users\73915\Downloads\5.png"

result = image_face_fusion(dict(template=template_path, user=user_path))

cv2.imwrite('reba.png', result[OutputKeys.OUTPUT_IMG])
# Out:
# 2023-12-30 00:06:13,698 - modelscope - INFO - model inference done
# True
