# %% [markdown]
# # 开源项目
#
# ## VideoChat
#
# * https://github.com/Henry-23/VideoChat
# * Demo： https://www.modelscope.cn/studios/AI-ModelScope/video_chat
# * 实时语音交互数字人，支持端到端语音方案（GLM-4-Voice - THG）和级联方案（ASR-LLM-TTS-THG）。可自定义形象与音色，无须训练，支持音色克隆，首包延迟低至3s。Real-time voice interactive digital human, supporting end-to-end voice solutions (GLM-4-Voice - THG) and cascaded solutions (ASR-LLM-TTS-THG). Customizable appearance and voice, supporting voice cloning, with initial package delay as low as 3s.
#
# ## ComfyUI + EchoMimic V2
#
# * https://www.toutiao.com/video/7441525810470584882/?log_from=d4cf64e05d0d_1735528961222
# * 半身像；
#
# ## lobe-vidol
#
# * https://github.com/lobehub/lobe-vidol
# * 虚拟人和 3D 模型聊天互动
#
# ## AniTalker
#
# * https://github.com/X-LANCE/AniTalker
# * 1.5k stars;
#
# ## 全身数字人One Shot one talk
#
# * to be released
#
# ## EchoMimic
#
# * https://www.toutiao.com/video/7441525810470584882/?log_from=1a3ff4f63d322_1734440847323
#
# ## Video retalking
# * https://github.com/OpenTalker/video-retalking
#
# ## Fay
# * https://github.com/TheRamU/Fay
# * https://www.toutiao.com/article/7228148056112366119/?log_from=edcaae1176527_1683192042943
#
# ## duix.ai
#
# * https://github.com/akan/duix.ai
# * https://huggingface.co/GuijiAI/duix.ai
# * offline 2d digitalhuman demo for edge devices (android/ios/etc.)
# * https://jexopm4t2a.feishu.cn/wiki/Ef1VwGHtRiUIQIkQl1hco2ISnFc
#
# ## 硅基虚拟人
#
#
# ## Linly-Talker
#
# * https://github.com/Kedreamix/Linly-Talker
#
# ## others
#
# * https://github.com/weihaox/awesome-digital-human
# * https://github.com/Zejun-Yang/AniPortrait
#
# ## open-chat-video-editor
# * https://github.com/SCUTlihaoyu/open-chat-video-editor
# * short video automatic generation tool
# * examples: https://mp.weixin.qq.com/s/cmGS6H1EGOxjiEZtuk0qvQ
#
# ### problem shot
# * librosa upgrade: pip install librosa -U
# * pip install faiss-cpu==1.7.2
# * pip install numpy==1.22.4
# * export LD_LIBRARY_PATH=${LD_LIBRARY_PATH}:/home/jeffye/ImageMagick-7.1.1-9/MagickWand/.libs:/usr/local/lib/
# * windows中
#   * https://download.imagemagick.org/script/download.php
#   * C:\Users\73915\.conda\envs\open_editor\lib\site-packages\moviepy\config.py
#   * IMAGEMAGICK_BINARY='C:\\Program Files\\ImageMagick-7.1.1-Q16-HDRI\\magick.exe'
#
# ## Bark
# * https://github.com/suno-ai/bark
# * 基于转换器的文本到音频模型。Bark可以生成高度逼真的多语言语音以及其他音频，包括音乐、背景噪音和简单的音效。
# * 该模型还可以产生非语言交流，如大笑、叹息和哭泣。为了支持研究社区，我们正在提供对预先训练的模型检查点的访问，以便进行推理。

# %%
from moviepy import *

video = VideoFileClip("myHolidays.p4").subclip(50,60)

# Make the text. Many more options are available.
txt_clip = ( TextClip("My Holidays 2013",fontsize=70,color='white')
             .with_position('center')
             .with_duration(10) )

result = CompositeVideoClip([video, txt_clip]) # Overlay text on video
result.write_videofile("myHolidays_edited.webm",fps=25) #
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\code\learn\pylearn\ML\digital_human\数字人.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/code/learn/pylearn/ML/digital_human/%E6%95%B0%E5%AD%97%E4%BA%BA.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from moviepy import *
#       <a href='vscode-notebook-cell:/d%3A/code/learn/pylearn/ML/digital_human/%E6%95%B0%E5%AD%97%E4%BA%BA.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> video = VideoFileClip("myHolidays.p4").subclip(50,60)
#       <a href='vscode-notebook-cell:/d%3A/code/learn/pylearn/ML/digital_human/%E6%95%B0%E5%AD%97%E4%BA%BA.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> # Make the text. Many more options are available.
#
# ModuleNotFoundError: No module named 'moviepy'

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ------------------------------------- 388.3/388.3 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 3.4/3.4 MB 10.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 22.6/22.6 MB 9.5 MB/s eta 0:00:00
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110773 sha256=51cb848914be6ee2ea97fe99e62f243746ceb420a78b1f0eb43d9aac31efb242
#   Stored in directory: c:\users\73915\appdata\local\pip\cache\wheels\fb\56\20\ea8039f0f19ff16db00131559d9290ff7cddf4711b64a3ff27
# Successfully built moviepy
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# ...
