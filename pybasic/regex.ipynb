# %% [markdown]
# # quick tutorial
#
# * https://www.w3schools.com/python/python_regex.asp
# * https://www.cnblogs.com/huxi/archive/2010/07/04/1771073.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # search

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
print(x)
# find all
import re

txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)

import re

txt = "The rain in Spain"
x = re.findall("Spain$", txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>
# ['ai', 'ai']
# ['Spain']

# %% [markdown]
# # compile
#
# ## match

# %%
import re

# Target String one
str1 = "Emma's luck numbers are 251 761 231 451"

# pattern to find three consecutive digits
string_pattern = r"\d{3}"
# compile string pattern to re.Pattern object
regex_pattern = re.compile(string_pattern)

# print the type of compiled pattern
print(type(regex_pattern))
# Output <class 're.Pattern'>

# find all the matches in string one
result = regex_pattern.findall(str1)
print(result)
# Output ['251', '761', '231', '451']

# Target String two
str2 = "Kelly's luck numbers are 111 212 415"
# find all the matches in second string by reusing the same pattern
result = regex_pattern.findall(str2)
print(result)
# Output ['111', '212', '415']
# Out:
# <class 're.Pattern'>
# ['251', '761', '231', '451']
# ['111', '212', '415']

# %%
regex_pattern = re.compile("^编辑.{2,5}$")
print(regex_pattern.match("编辑 刘佳妮"))
# Out:
# <re.Match object; span=(0, 6), match='编辑 刘佳妮'>

# %% [markdown]
# ## sub

# %%
text = "文旅部今晚公布，今年中秋国庆8天长假，国内旅游出游人数8.26亿-今日头条"
pattern = re.compile("-今日头条$")
print(pattern.sub("", text))
