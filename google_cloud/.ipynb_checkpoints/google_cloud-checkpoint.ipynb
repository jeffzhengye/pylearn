# %% [markdown]
# # Call dialogflow with python api
# ## precondition
# you have to download your json key, and ***export GOOGLE_APPLICATION_CREDENTIALS="/mnt/d/code/sabala/weather-e6aad-0371e7c946bc.json"***

# %%
# check firewall
# !rm index.html*
# !wget www.google.com
# Out:
# --2022-06-08 22:34:17--  http://www.google.com/
# Connecting to 172.26.224.1:7890... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ]  13.45K  --.-KB/s    in 0.06s
#
# 2022-06-08 22:34:18 (208 KB/s) - ‘index.html’ saved [13770]

# %%
import uuid
from google.cloud import dialogflow

session_client = dialogflow.SessionsClient()

# session format: 'projects/*/locations/*/agent/environments/*/users/*/sessions/*'.
def get_session(project_id, session_id, env=None):
    """
    Using the same `session_id` between requests allows continuation
    of the conversation.
    :return: session is a str
    """
    if env is None:
        session = session_client.session_path(project_id, session_id)
        return session
    else:
        assert isinstance(env, str)
        return f"projects/{project_id}/agent/environments/{env}/sessions/{session_id}"
    

# [START dialogflow_detect_intent_text]
def detect_intent_texts(project_id, session_id, text, language_code, env=None):
    """Returns the result of detect intent with texts as inputs.

    Using the same `session_id` between requests allows continuation
    of the conversation."""
    session= get_session(project_id, session_id, env=env)
    print("Session path: {}\n".format(session))

    text_input = dialogflow.TextInput(text=text, language_code=language_code)
    query_input = dialogflow.QueryInput(text=text_input)

    response = session_client.detect_intent(
        request={"session": session, "query_input": query_input}
    )   

    return response

# %%
# set credentials, this is a must

import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] ="/mnt/d/code/sabala/mega-sabala-9ibe-940e7527ac9b.json"

# %% [markdown]
# ## examples of making session url

# %%
from google.cloud import dialogflow

project_id = "sabala-348110"

session_id = str(uuid.uuid4())
# texts = ["Me toque uma música", "toca nos 80", "Tocar música clássica", "parar música"][-1:]
language_code = "en-US"

session = get_session(project_id, session_id, env='new')
session
# Out:
# 'projects/sabala-348110/agent/environments/new/sessions/4908ce86-2141-4128-a025-0cd3cb3c325c'

# %% [markdown]
# # visit Mega Agent and print

# %%
project_id = "mega-sabala-9ibe"

session_id = str(uuid.uuid4())
texts = ["how's the weather today", "Você pode me dizer a maneira mais fácil de ganhar dinheiro?"]
texts = ["parar música"]
language_code = "pt-BR"
response = detect_intent_texts(
        project_id, session_id, texts[0], language_code
)
# Out:
# Session path: projects/mega-sabala-9ibe/agent/sessions/53ea03ea-6486-470a-b30b-de3cabddfaaa

# %%
response.output_audio = "None"
print("=" * 20)
print("Query text: {}".format(response.query_result.query_text))
print(
    "Detected intent: {} (confidence: {})\n".format(
        response.query_result.intent.display_name,
        response.query_result.intent_detection_confidence,
    )
)
print("Fulfillment text: {}\n".format(response.query_result.fulfillment_text))
print("Fulfillment Full: \n{}\n".format(response))
print(type(response))
# Out:
# ====================
# Query text: parar música
# Detected intent: MediaControl_Stop (confidence: 1.0)
#
# Fulfillment text: parou de tocar.
#
# Fulfillment Full:
# response_id: "97d459e4-bb13-4b62-a33a-19651db8731a-1e65c7b4"
# query_result {
#   query_text: "parar m\303\272sica"
#   parameters {
#   }
#   all_required_params_present: true
#   fulfillment_text: "parou de tocar."
#   fulfillment_messages {
#     text {
#       text: "parou de tocar."
#     }
#   }
#   webhook_payload {
#     fields {
#       key: "google"
#       value {
#         struct_value {
#           fields {
#             key: "expectUserResponse"
#             value {
#               bool_value: true
#             }
#           }
#           fields {
#             key: "richResponse"
#             value {
#               struct_value {
#                 fields {
#                   key: "items"
#                   value {
#                     list_value {
#                       values {
#                         struct_value {
#                           fields {
#                             key: "simpleResponse"
#                             value {
#                               struct_value {
#                                 fields {
#                                   key: "displayText"
#                                   value {
#                                     string_value: "parou de tocar."
#                                   }
#                                 }
#                                 fields {
#                                   key: "textToSpeech"
#                                   value {
#                                     string_value: "parou de tocar."
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     fields {
#       key: "picoai"
#       value {
#         struct_value {
#           fields {
#             key: "message"
#             value {
#               string_value: "{\"outputText\": \"parou de tocar.\", \"success\": true}"
#             }
#           }
#         }
#       }
#     }
#   }
#   output_contexts {
#     name: "projects/mega-sabala-9ibe/agent/sessions/53ea03ea-6486-470a-b30b-de3cabddfaaa/contexts/__mega_agent_context__"
#     lifespan_count: 2147483647
#     parameters {
#       fields {
#         key: "__most_recent_agent_ids__"
#         value {
#           list_value {
#             values {
#               string_value: "4e05f70d-db24-4a56-8aff-d764e59245b2"
#             }
#           }
#         }
#       }
#     }
#   }
#   intent {
#     name: "projects/others-sabala-eonj/agent/intents/ca9aec20-f3de-45aa-a96e-9208467eb10f"
#     display_name: "MediaControl_Stop"
#     end_interaction: true
#   }
#   intent_detection_confidence: 1.0
#   diagnostic_info {
#     fields {
#       key: "end_conversation"
#       value {
#         bool_value: true
#       }
#     }
#     fields {
#       key: "webhook_latency_ms"
#       value {
#         number_value: 317.0
#       }
#     }
#   }
#   language_code: "pt-br"
# }
# webhook_status {
#   message: "Webhook execution successful"
# }
# output_audio: "6\211\336"
# output_audio_config {
#   audio_encoding: OUTPUT_AUDIO_ENCODING_LINEAR_16
#   synthesize_speech_config {
#     speaking_rate: 1.0
#     voice {
#     }
#   }
# }
#
#
# <class 'google.cloud.dialogflow_v2.types.session.DetectIntentResponse'>

# %% [markdown]
# # visit media/Music Agent

# %% [markdown]
# ## visit the default one: draft

# %%
project_id = "sabala-348110"

session_id = str(uuid.uuid4())
texts = ["Me toque uma música", "toca nos 80", "Tocar música clássica", "parar música"]
language_code = "en-US"

response = detect_intent_texts(
        project_id, session_id, texts[-1], language_code, env='before_tf'
)
# Out:
# Session path: projects/sabala-348110/agent/environments/before_tf/sessions/d5da4a02-3901-42d4-8ec8-83afcd92b8e7

# %%
print( [(_, type(_)) for _ in dir(response) if not _.startswith("_")] )
response.output_audio = "None"
print(response.query_result.intent)
# Out:
# [('output_audio', <class 'str'>), ('output_audio_config', <class 'str'>), ('query_result', <class 'str'>), ('response_id', <class 'str'>), ('webhook_status', <class 'str'>)]
# name: "projects/sabala-348110/agent/intents/4bde314e-8feb-4ad1-b1fc-3fe451a7b431"
# display_name: "PlayMusic"
# end_interaction: true

# %% [markdown]
# ## visit active version in a specified environment

# %%
response = detect_intent_texts(
        project_id, session_id, texts[-1], language_code, env='before_tf'
)
# Out:
# Session path: projects/sabala-348110/agent/environments/before_tf/sessions/d5da4a02-3901-42d4-8ec8-83afcd92b8e7

# %%
print(response)
# Out:
# response_id: "663746f1-5693-4599-b3ed-9163c8a5925b-3d49d937"
# query_result {
#   query_text: "parar m\303\272sica"
#   parameters {
#     fields {
#       key: "artist"
#       value {
#         string_value: ""
#       }
#     }
#     fields {
#       key: "genre"
#       value {
#         string_value: ""
#       }
#     }
#     fields {
#       key: "title"
#       value {
#         string_value: ""
#       }
#     }
#   }
#   all_required_params_present: true
#   fulfillment_text: "Agora tocando Nem Amantes Nem Amigos, Trio Parada Dura"
#   fulfillment_messages {
#     text {
#       text: "Agora tocando Nem Amantes Nem Amigos, Trio Parada Dura"
#     }
#   }
#   webhook_payload {
#     fields {
#       key: "google"
#       value {
#         struct_value {
#           fields {
#             key: "expectUserResponse"
#             value {
#               bool_value: true
#             }
#           }
#           fields {
#             key: "richResponse"
#             value {
#               struct_value {
#                 fields {
#                   key: "items"
#                   value {
#                     list_value {
#                       values {
#                         struct_value {
#                           fields {
#                             key: "simpleResponse"
#                             value {
#                               struct_value {
#                                 fields {
#                                   key: "displayText"
#                                   value {
#                                     string_value: "Agora tocando Nem Amantes Nem Amigos, Trio Parada Dura"
#                                   }
#                                 }
#                                 fields {
#                                   key: "textToSpeech"
#                                   value {
#                                     string_value: "Agora tocando Nem Amantes Nem Amigos, Trio Parada Dura"
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     fields {
#       key: "picoai"
#       value {
#         struct_value {
#           fields {
#             key: "message"
#             value {
#               string_value: "{\"playCommand\": \"PLAY\", \"currentTrack\": {\"title\": \"Nem Amantes Nem Amigos\", \"artist\": \"Trio Parada Dura\", \"album\": \"Trio Parada Dura as 20+\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2020/10/15_1154/NemAmantesNemAmigos01.m3u8\"}, \"playlist\": [{\"title\": \"Nem Amantes Nem Amigos\", \"artist\": \"Trio Parada Dura\", \"album\": \"Trio Parada Dura as 20+\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2020/10/15_1154/NemAmantesNemAmigos01.m3u8\"}, {\"title\": \"Engenho Velho\", \"artist\": \"Wilson Paim\", \"album\": \"Wilson Paim Interpreta Salvador Lamberty, Vol III: Bras\\u00e3o de Pampa\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2020/09/25_0903/EngenhoVelho.m3u8\"}, {\"title\": \"Malmequer pequenino (Small Chrysanthemum)\", \"artist\": \"Am\\u00e1lia Rodrigues,Studio ensemble\", \"album\": \"The Queen of Fado II\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/20200811_1037/MalmequerpequeninoSmallChrysanthemum.m3u8\"}, {\"title\": \"Anitta, Lexa, Luisa Sonza feat. MC Rebecca - Combatchy [Official Music Video]\", \"artist\": \"Anitta\", \"album\": \"album\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2021/04/06_1116/AnittaAnittaLexaLuisaSonzaFeatMcRebeccaCombatchyOfficialMusicVideo.m3u8\"}, {\"title\": \"Gosto de batom\", \"artist\": \"Lulu Santos\", \"album\": \"E-Collection\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2020/09/22_1036/Gostodebatom.m3u8\"}, {\"title\": \"King Daddy\", \"artist\": \"Daddy Yankee\", \"album\": \"Barrio Fino (Bonus Track Version)\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/20200813_0839/KingDaddy.m3u8\"}, {\"title\": \"Coladinho - Ao Vivo\", \"artist\": \"Luan Santana\", \"album\": \"Quando Chega a Noite (Ao Vivo)\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/20200827_1340/ColadinhoAoVivo.m3u8\"}, {\"title\": \"At My Worst\", \"artist\": \"Pink Sweat$\", \"album\": \"At My Worst (Gustixa Remix)\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2021/07/16_0900/AtMyWorst3.m3u8\"}, {\"title\": \"EU AMO VOC\\u00ca - Ao Vivo\", \"artist\": \"Latino\", \"album\": \"Latino: 10 Anos de Sucessos (Ao Vivo)\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/20200821_1604/EUAMOVOCE\\u0302AoVivo.m3u8\"}, {\"title\": \"Atentado Pessoal\", \"artist\": \"Z\\u00e9 Neto & Cristiano\", \"album\": \"Z\\u00e9 Neto & Cristiano Voz & Viol\\u00e3o\", \"playUrl\": \"http://d3vdmt2zch0eui.cloudfront.net/brazil-pop-artist/2021/07/14_0900/AtentadoPessoal.m3u8\"}], \"outputText\": \"Agora tocando Nem Amantes Nem Amigos, Trio Parada Dura\", \"success\": true}"
#             }
#           }
#         }
#       }
#     }
#   }
#   intent {
#     name: "projects/sabala-348110/agent/intents/4bde314e-8feb-4ad1-b1fc-3fe451a7b431"
#     display_name: "PlayMusic"
#     end_interaction: true
#   }
#   intent_detection_confidence: 0.6556375622749329
#   diagnostic_info {
#     fields {
#       key: "end_conversation"
#       value {
#         bool_value: true
#       }
#     }
#     fields {
#       key: "webhook_latency_ms"
#       value {
#         number_value: 232.0
#       }
#     }
#   }
#   language_code: "pt-br"
# }
# webhook_status {
#   message: "Webhook execution successful"
# }
# output_audio: "RIFF\270q\003\000WAVEfmt \020\000\000\000\001\000\001\000\300]\000\000\200\273\000\000\002\000\020\000data\224q\003\000\000\000\377\377\377\377\377\377\377\377\377\377\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\377\377\377\377\376\377\376\377\375\377\376\377\377\377\377\377\000\000\002\000\003\000\005\000\t\000\013\000\016\000\017\000\022\000\022\000\022\000\020\000\017\000\016\000\014\000\t\000\005\000\001\000\001\000\375\377\372\377\367\377\366\377\357\377\357\377\354\377\354\377\353\377\352\377\355\377\356\377\357\377\357\377\363\377\366\377\371\377\375\377\377\377\000\000\001\000\003\000\007\000\t\000\013\000\017\000\016\000\017\000\017\000\016\000\016\000\013\000\t\000\007\000\004\000\001\000\377\377\374\377\372\377\365\377\364\377\357\377\355\377\353\377\350\377\347\377\343\377\345\377\347\377\346\377\346\377\347\377\351\377\352\377\355\377\363\377\366\377\371\377\374\377\000\000\000\000\001\000\004\000\010\000\n\000\014\000\016\000\017\000\016\000\r\000\017\000\016\000\014\000\t\000\007\000\007\000\002\000\000\000\375\377\371\377\366\377\362\377\355\377\352\377\350\377\344\377\343\377\337\377\337\377\335\377\334\377\336\377\336\377\337\377\337\377\337\377\344\377\346\377\351\377\354\377\361\377\365\377\372\377\372\377\377\377\000\000\002\000\007\000\006\000\n\000\013\000\013\000\016\000\020\000\020\000\020\000\r\000\014\000\013\000\006\000\003\000\003\000\000\000\374\377\366\377\363\377\357\377\351\377\346\377\341\377\335\377\333\377\327\377\324\377\324\377\321\377\320\377\323\377\322\377\325\377\325\377\330\377\332\377\334\377\341\377\346\377\352\377\360\377\364\377\372\377\376\377\000\000\002\000\006\000\013\000\016\000\016\000\023\000\024\000\024\000\024\000\030\000\026\000\026\000\022\000\021\000\014\000\n\000\010\000\003\000\000\000\376\377\371\377\366\377\363\377\360\377\353\377\350\377\344\377\340\377\342\377\334\377\333\377\334\377\334\377\333\377\335\377\334\377\340\377\342\377\344\377\350\377\356\377\354\377\362\377\367\377\371\377\375\377\000\000\001\000\005\000\014\000\017\000\020\000\022\000\024\000\024\000\030\000\032\000\030\000\030\000\034\000\033\000\026\000\026\000\022\000\016\000\017\000\t\000\006\000\004\000\377\377\377\377\372\377\370\377\362\377\361\377\357\377\354\377\351\377\350\377\344\377\345\377\345\377\346\377 ...
# output_audio_config {
#   audio_encoding: OUTPUT_AUDIO_ENCODING_LINEAR_16
#   synthesize_speech_config {
#     speaking_rate: 1.0
#   }
# }

# %% [markdown]
# # Webhook handle
# * https://github.com/googleapis/python-dialogflow/blob/HEAD/samples/snippets/webhook.py

# %%
# TODO: change the default Entry Point text to handleWebhook

def handleWebhook(request):

    req = request.get_json()

    responseText = ""
    intent = req["queryResult"]["intent"]["displayName"]

    if intent == "Default Welcome Intent":
        responseText = "Hello from a GCF Webhook"
    elif intent == "get-agent-name":
        responseText = "My name is Flowhook"
    else:
        responseText = f"There are no fulfillment responses defined for Intent {intent}"

    # You can also use the google.cloud.dialogflowcx_v3.types.WebhookRequest protos instead of manually writing the json object
    res = {"fulfillmentMessages": [{"text": {"text": [responseText]}}]}

    return res

# %%
handleWebhook(response)
