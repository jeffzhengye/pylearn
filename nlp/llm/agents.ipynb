# %% [markdown]
# # tutorials
#
# # qwen
#
# ## agent development
#
# * https://help.aliyun.com/zh/dashscope/developer-reference/model-plugin-quick-start/?spm=a2c4g.11186623.0.0.17c53709kQCxCE
#
# # modelscope-agent
#
# * https://github.com/modelscope/modelscope-agent

# %% [markdown]
# 9# tools
#
# ## liongai - worthy to watch, not ready now
#
# * https://github.com/lion-agi/lionagi
# * https://lionagi.readthedocs.io/en/latest/
# * Towards Automated General Intelligence: agent framework tailored for big data analysis with advanced machine learning tools. Designed for data-centric, production-level projects. Lionagi allows flexible and rapid design of agentic workflow, customed for your own data. Lionagi agents can manage and direct other agents, can also use multiple different tools in parallel.
# * ![image.png](attachment:image.png)
#
# ## livekit agents
#
# * The Agents framework allows you to build AI-driven server programs that can see, hear, and speak in realtime. Your agent connects with end user devices through a LiveKit session. During that session, your agent can process text, audio, images, or video streaming from a user's device, and have an AI model generate any combination of those same modalities as output, and stream them back to the user.
# * Realtime SDKs	Browser · iOS/macOS/visionOS · Android · Flutter · React Native · Rust · Node.js · Python · Unity · Unity (WebGL)

# %% [markdown]
# # Agent projects
#
# ## financial-agent
#
# * https://github.com/virattt/financial-agent
#
# ## agno
#
# * https://github.com/agno-agi/agno
# * pure python, no graphs, chains; ~10,000x faster than LangGraph; multi agent;
# *
# *
# Level 0: Agents with no tools (basic inference tasks).
# Level 1: Agents with tools for autonomous task execution.
# Level 2: Agents with knowledge, combining memory and reasoning.
# Level 3: Teams of agents collaborating on complex workflows.
